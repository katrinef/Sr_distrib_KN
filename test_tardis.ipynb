# %%
from tardis import run_tardis
from tardis.io.atom_data.util import download_atom_data
# Out:
# /home/katrine/anaconda3/envs/tardis/lib/python3.7/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)

# %%
sim = run_tardis('tardis_example.yml')
# Out:
# [tardis.plasma.standard_plasmas][INFO   ]  Reading Atomic Data from tardis_df_Ta.h5 (standard_plasmas.py:87)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3418: PerformanceWarning: indexing past lexsort depth may impact performance.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#  (warnings.py:110)
# [tardis.io.atom_data.base][INFO   ]  Read Atom Data with UUID=dbd780e43ae711eb89c3484520e23618 and MD5=374430f09fd8863258d50592e4017ce6. (base.py:187)
# [tardis.io.atom_data.base][INFO   ]  Non provided atomic data: synpp_refs, photoionization_data (base.py:193)
# [tardis.simulation.base][INFO   ]  Starting iteration 1/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 7.89443e+42 erg / s Luminosity absorbed = 2.69906e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	             t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      9926.501965  10086.113777  0.400392  0.520457
# 	5      9852.611678  10098.293538  0.211205  0.209237
# 	10     9779.813302   9929.074518  0.142695  0.128422
# 	15     9708.082813   9622.527271  0.104556  0.096598
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 9933.952 K -- next t_inner 11507.112 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 2/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.40210e+43 erg / s Luminosity absorbed = 5.03316e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      10086.113777  11423.628622  0.520457  0.571420
# 	5      10098.293538  11223.505900  0.209237  0.249786
# 	10      9929.074518  10974.456494  0.128422  0.156212
# 	15      9622.527271  10629.175020  0.096598  0.117858
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 11507.112 K -- next t_inner 10001.875 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 3/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.27279e+42 erg / s Luminosity absorbed = 2.61841e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      11423.628622  10442.081560  0.571420  0.461450
# 	5      11223.505900  10573.496303  0.249786  0.184502
# 	10     10974.456494  10376.735093  0.156212  0.115882
# 	15     10629.175020   9975.294922  0.117858  0.088336
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 10001.875 K -- next t_inner 11317.751 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 4/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.32923e+43 erg / s Luminosity absorbed = 4.54906e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      10442.081560  11420.874466  0.461450  0.532664
# 	5      10573.496303  11312.222638  0.184502  0.227937
# 	10     10376.735093  11023.300220  0.115882  0.145196
# 	15      9975.294922  10702.166179  0.088336  0.108072
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 11317.751 K -- next t_inner 10103.349 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 5/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8.52456e+42 erg / s Luminosity absorbed = 2.81332e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      11420.874466  10503.830955  0.532664  0.467869
# 	5      11312.222638  10736.183194  0.227937  0.178621
# 	10     11023.300220  10557.588171  0.145196  0.110604
# 	15     10702.166179  10106.364841  0.108072  0.086355
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 10103.349 K -- next t_inner 11262.478 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 6/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.30286e+43 erg / s Luminosity absorbed = 4.46282e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      10503.830955  11379.424792  0.467869  0.530290
# 	5      10736.183194  11304.815192  0.178621  0.227378
# 	10     10557.588171  11086.107190  0.110604  0.140485
# 	15     10106.364841  10644.880110  0.086355  0.107964
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 11262.478 K -- next t_inner 10155.234 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 7/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 8
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 10324.560 K -- next t_inner 11047.895 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 16/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.20632e+43 erg / s Luminosity absorbed = 4.13900e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      10657.227591  11220.310754  0.484443  0.517269
# 	5      10809.523565  11184.436395  0.191815  0.214402
# 	10     10593.422537  10944.138892  0.118251  0.136299
# 	15     10147.846476  10613.698821  0.092112  0.101093
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 11047.895 K -- next t_inner 10352.685 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 17/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 9.39854e+42 erg / s Luminosity absorbed = 3.09965e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      11220.310754  10777.577661  0.517269  0.467759
# 	5      11184.436395  10886.329930  0.214402  0.187051
# 	10     10944.138892  10611.204595  0.136299  0.118467
# 	15     10613.698821  10326.198463  0.101093  0.087566
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 10352.685 K -- next t_inner 10990.751 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 18/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.18857e+43 erg / s Luminosity absorbed = 3.98782e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      10777.577661  11169.474359  0.467759  0.513538
# 	5      10886.329930  11204.726705  0.187051  0.211689
# 	10     10611.204595  10898.936826  0.118467  0.135515
# 	15     10326.198463  10533.335814  0.087566  0.102002
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 10990.751 K -- next t_inner 10375.739 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 19/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 9.45418e+42 erg / s Luminosity absorbed = 3.15651e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Plasma stratification:
# 	              t_rad    next_t_rad         w    next_w
# 	Shell
# 	0      11169.474359  10776.013811  0.513538  0.473512
# 	5      11204.726705  10861.054246  0.211689  0.188140
# 	10     10898.936826  10676.989802  0.135515  0.116453
# 	15     10533.335814  10317.195880  0.102002  0.088469
#
#  (base.py:437)
# [tardis.simulation.base][INFO   ]  t_inner 10375.739 K -- next t_inner 10982.765 K (base.py:440)
# [tardis.simulation.base][INFO   ]  Starting iteration 20/20 (base.py:326)
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# Running post-merge numba montecarlo (with C close lines)!
# [tardis.simulation.base][INFO   ]  Luminosity emitted = 1.18109e+43 erg / s Luminosity absorbed = 4.01143e+42 erg / s Luminosity requested = 1.05928e+43 erg / s (base.py:451)
# [tardis.simulation.base][INFO   ]  Simulation finished in 20 iterations and took 51.04 s (base.py:384)

# %%
# %pylab inline

spectrum = sim.runner.spectrum
spectrum_virtual = sim.runner.spectrum_virtual
spectrum_integrated = sim.runner.spectrum_integrated

figure(figsize=(10,6))
plot(spectrum.wavelength, spectrum.luminosity_density_lambda, label='normal packets')
plot(spectrum.wavelength, spectrum_virtual.luminosity_density_lambda, label='virtual packets')
plot(spectrum.wavelength, spectrum_integrated.luminosity_density_lambda, label='formal integral')
xlabel('Wavelength [$\AA$]')
ylabel('Luminosity [erg/s/$\AA$]')
legend()
xlim(3000, 9000)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [py.warnings         ][WARNING]  /home/katrine/anaconda3/envs/tardis/lib/python3.7/site-packages/astropy/units/equivalencies.py:124: RuntimeWarning: divide by zero encountered in double_scalars
#   (si.m, si.Hz, lambda x: _si.c.value / x),
#  (warnings.py:110)
# (3000.0, 9000.0)
